# %% [markdown]
# # Prácticas avanzadas:
#
# - Cambio de headers
# - Camuflando selenium
# - Cookies
# - cURL

# %%
# https://intoli.com/blog/making-chrome-headless-undetectable/
from utils import init_chrome

from bs4 import BeautifulSoup
#from selenium import webdriver
from seleniumwire import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

from fake_useragent import UserAgent
import random
from xlsxwriter import Workbook
import time
import datetime
from datetime import datetime, date
from datetime import timedelta
from time import sleep
import re
import pandas as pd
import numpy as np
import socket
import sys
import random
import os
import csv,operator
import unicodedata
from webdriver_manager.chrome import ChromeDriverManager
from urllib.parse import parse_qs
import requests as rq

# %%
os.getcwd()
# Out:
# '/home/matias/Humai/Manu'

# %%
#killall chromedriver
country= 'ARG'
url = 'https://www.volaris.com/?currency=MXN'
print(os.getcwd())
start = datetime.today() - timedelta(hours=3)
formato = "%Y%m%d"
formato2 = "%Y-%m-%d %H:%M"

ua = UserAgent()
user_agent = ua.random #print(userAgent)
driver = init_chrome_f()
# Out:
# /home/matias/Humai/Manu
# headless off

# %%
#actions = ActionChains(driver)

_ = driver.execute_script("""// overwrite the `languages` property to use a custom getter
Object.defineProperty(navigator, 'languages', {
  get: function() {
    return ['en-US', 'en'];
  },
});

// overwrite the `plugins` property to use a custom getter
Object.defineProperty(navigator, 'plugins', {
  get: function() {
    // this just needs to have `length > 0`, but we could mock the plugins too
    return [1, 2, 3, 4, 5];
  },
});""")


driver.get(url)
sleep(random.randint(1,7))
driver.maximize_window()

# %%
# one_way selectect
driver.find_element_by_id("input_origin").click()
sleep(random.randint(1,2))
driver.find_element_by_xpath("//*[@id=\"BookingWidgetFlight\"]/div/div/div[1]/div/div/div[2]/label[2]/span").click()

# Enter origin
origin = 'Acapulco'
sleep(random.randint(1,2))
driver.find_element_by_id("input_origin").send_keys(origin)

# Select origin
actions.send_keys(Keys.DOWN)
actions.send_keys(Keys.ENTER)
actions.perform()


# Enter dest
destination = 'Guadalajara'
sleep(random.randint(1,2))
driver.find_element_by_id("input_destination").send_keys(destination)

# Select dest
actions.send_keys(Keys.DOWN)
actions.send_keys(Keys.ENTER)
actions.perform()

# Select date input
driver.find_element_by_id("text_input_date_from").click()

# Select date
month_current = 5
day_target, month_target, year_target = 3, 6, 2020
month_target -= 1
month_current -= 1
# meses estan desfasados por uno
for i in range(month_target - month_current):    
    # driver.find_element_by_xpath(f"//a[@data-handler = 'prev']").click()
    try:
        driver.find_element_by_xpath(f"//a[@data-handler = 'next']").click()
    except:
        driver.find_element_by_xpath(f"//*[text () = 'Ok, got it']").click()
        sleep(random.randint(1,2))
        driver.find_element_by_xpath(f"//a[@data-handler = 'next']").click()


driver.find_element_by_xpath(f"//td[(@data-handler = 'selectDay') and (@data-month = '{month_target}')]/a[@aria-label = ' {day_target}, {year_target}']").click()

driver.find_element_by_xpath("//div[@id = 'find-flight']").click()

driver.switch_to_window(driver.window_handles[1])
driver.close()

driver.switch_to_window(driver.window_handles[0])
print(driver.find_elements_by_xpath("//div[@class ='flight-fare-row flight-tickets flight-item flight-item-row']")[0].text)

elems = driver.find_elements_by_xpath("//div[@class ='row flight-item-list']")
data = [e.text.split('\n') for e in elems][::2]
data


for request in driver.requests:
    if 'https://www.volaris.com/Flight/Select' == request.path:
        r = request



##### 

post_url = "https://www.volaris.com/Home/SubmitFlight"
ex ="""name=0&data_input_origin=ACA&data_input_destination=GDL&hf_countrycode_origin=MX&hf_countrycode_destination=MX&data_CBX_origin=0&data_CBX_destination=0&data_HotelTab_destination=GDL&data_origin_countryCode=&data_destination_countryCode=&PromoCode=&tripType=0&Destination=Guadalajara&input_date_from=06%2F11%2F2020&input_date_to=06%2F16%2F2020&txtAdultValue=1&txtMinorValue=0&txtInfantValue=0&txtPassportValue=0&dniValue=0"""
ex = {k:v[0] for k,v in parse_qs(ex).items()}
#ex['data_input_origin'] = 'ATL'

cookies = {
    'utagdb': 'true',
    'ASP.NET_SessionId': 'fu2mmomruuvdwwry0gzovscs',
    '__RequestVerificationToken': 'N7zL_dSMkZQon6CPbcEQxnA15yHb0au4VjnzjAYWAv-l-c8irIL_uqV5iBC9UBHA5hHNAt7d0CB5iA9INcg1J7N66ulVeOsV2phrX62yzI2q6TMdj5WHOGjwcMZLnLNGBYxeQeNRd7M84tpm-2B7Vw2',
    'nlbi_2041990': '18BaHwKsY1L674lhqQtRMgAAAABhCaLI3jygKeNdc/W6tcJl',
    'visid_incap_2041990': 'mS2qeGXPSfa0YwE2r3fKkEV0zF4AAAAAQUIPAAAAAABF0zmWZg/emG04GUlLUGYf',
    'incap_ses_785_2041990': '7+j1GycW+1nzVgnvYuHkCkZ0zF4AAAAAeirFCa5qclpbvG0TJvA3Ww==',
    'visid_incap_2042180': 'Ni6gn9W+S+eBlKHKNexqqEd0zF4AAAAAQUIPAAAAAACQ7wFqcfEjrKx6Qnm/UOsg',
    'incap_ses_785_2042180': 'GNyqGu5nMj70VwnvYuHkCkd0zF4AAAAA/SYD3Rsi4jwOghTOK9I/ZA==',
    'optimizelyEndUserId': 'oeu1590457416154r0.11094148501220635',
    '_gcl_au': '1.1.1343718800.1590457417',
    'VolarisMcpAlertFlag': '25-05-2020',
    'CONSENTMGR': 'ts:1527114936092%7Cconsent:true%7Cc1:1%7Cc2:1%7Cc3:1%7Cc4:1%7Cc5:1%7Cc6:1%7Cc7:1%7Cc8:1%7Cc9:1%7Cc10:1%7Cc11:1%7Cc12:1%7Cc13:1%7Cc14:1%7Cc15:1',
    '_ga': 'GA1.2.1410783355.1590457419',
    '_gid': 'GA1.2.855285726.1590457419',
    'viq': 'Volaris',
    '_fbp': 'fb.1.1590457419044.1763083144',
    'emcid': '3Okmmp',
    '_up': '1.2.484761735.1590457420',
    'intent_media_prefs': '',
    '_lo_bn': '1',
    'bid_volf69p76yuivxh2b31ccu0h1wxwmcms': '287b74de-ede5-4bb7-8fee-e86e0b10b5f1',
    'bx_bucket_number': '12',
    'im_puid': '4d56b643-6efe-4c3d-b5d7-5b4661778a78',
    'im_puid_ssn': '4d56b643-6efe-4c3d-b5d7-5b4661778a78',
    'im_snid': 'f60106d9-e45d-4e55-b639-fa3b87d939f2',
    'cookie_num_pax_inf': '0',
    'IM_eu_freq_cap': 'Y',
    'amplitude_device_id': 'undefined',
    'TBMCookie_7919713700214170376': '359910001590457799rJlDss5fVDMau89ifSS/exp9eUU=',
    'utag_main': 'v_id:01724ea63b1e000d8b43e81f889e0306c002506400868$_sn:1$_ss:0$_st:1590459452390$ses_id:1590457416479%3Bexp-session$_pn:3%3Bexp-session',
    'amplitude_id_a0709c60168afb2099d90b24c57f6c93_officialvolaris.com': 'eyJkZXZpY2VJZCI6IjFhN2M0NjQxLWZiMTAtNDEzOC04YzlkLTdiYzdkMjZiNjQxZVIiLCJ1c2VySWQiOm51bGwsIm9wdE91dCI6ZmFsc2UsInNlc3Npb25JZCI6MTU5MDQ1NzQxODg5NiwibGFzdEV2ZW50VGltZSI6MTU5MDQ1NzY1MzU3MiwiZXZlbnRJZCI6MywiaWRlbnRpZnlJZCI6Mywic2VxdWVuY2VOdW1iZXIiOjZ9',
    '_uetsid': 'c8892370-4c2f-b1a1-cba8-f47681528612',
    '_dc_gtm_UA-18158250-1': '1',
}

headers = {
    'authority': 'www.volaris.com',
    'cache-control': 'max-age=0',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/29.0.1547.62 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-user': '?1',
    'sec-fetch-dest': 'document',
    'referer': 'https://www.volaris.com/?currency=MXN',
    'accept-language': 'en-US,en;q=0.9',
}

r = requests.get('https://www.volaris.com/Flight/Select', headers=headers, cookies=cookies)

#driver.close()

# driver.find_elements_by_xpath("//ul/li/div[@tabindex='-1']")[1].send_keys(Keys.ENTER)
# driver.switch_to_window(driver.window_handles[0])
#rq.get(post_url, headers={'user-agent':ua}, data=ex)

driver_cookies = driver.get_cookies()
c = {c['name']:c['value'] for c in driver_cookies}
r = requests.get('https://www.volaris.com/Flight/Select', data=ex, headers=headers, cookies=c)

#<span class="amount">
#$19,581.05 <span class="currency"> ARS</span>
#</span>
