# %% [markdown]
# ## Rappi
# https://www.rappi.com.ar/restaurantes/rapanui
#
# Gráficar el histograma de precios de rapanui

# %%
# !curl 'https://services.rappi.com.ar/api/restaurant-bus/store/friendly-url/rapanui' \
  -H 'authority: services.rappi.com.ar' \
  -H 'accept: application/json, text/plain, */*' \
  -H 'dnt: 1' \
  -H 'authorization: Bearer eWIydHdobVp0aTVlSEpnTGdwR3I3aTJzNEFQaUZT' \
  -H 'user-agent: Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.105 Safari/537.36' \
  -H 'content-type: application/json' \
  -H 'origin: https://www.rappi.com.ar' \
  -H 'sec-fetch-site: same-site' \
  -H 'sec-fetch-mode: cors' \
  -H 'sec-fetch-dest: empty' \
  -H 'referer: https://www.rappi.com.ar/restaurantes/rapanui' \
  -H 'accept-language: es-US,es;q=0.9,en-US;q=0.8,en;q=0.7,es-419;q=0.6,ja;q=0.5' \
  --data-binary '{"store_type":"restaurant","lat":-34.5887308,"lng":-58.4302191}' \
  --compressed
# Out:
# {"store_id":114256,"super_store_id":182,"is_open_today":true,"logo":"114256-1548180793.png","brand_name":"Rapanui","brand_id":3269,"store_type":"restaurant","background":"franui-1575058019345.png","name":"Rapanui - Malabia","address":"Malabia 2014","schedules":[{"day":"thu","open_time":"11:00:00","close_time":"23:55:00"}],"delivery_methods":["delivery"],"eta":"30 min","eta_value":30,"zone_id":425012,"has_coverage":true,"percentage_service_fee":0.0,"has_promise":false,"is_marketplace":false,"delivery_price":59.0,"has_comments":false,"has_bio_packaging":false,"location":[-58.423092306134,-34.588039040709],"is_favorite":false,"tags":[{"id":4,"name":"Postres"},{"id":257,"name":"Helados"}],"is_currently_available":true,"rating":{"store_id":114256,"score":4.9,"total_reviews":6074},"saturation":{"store_id":114256,"saturations":{"geographical":"none","store":"none"},"eta":{"value":22.0,"action":0},"price":{"value":0.0,"action":0},"switches":{"high_demand":0,"cash":1,"checkout_confirmation":0
# ...

# %%
# Reemplazar esta funcion para que devuelva la lista de precios real
def precios_de_rapanui():
    # COMPLETAR
    return [200,300,500,500,500,310,200,250]

# %%
import pandas as pd
rapanui_df = pd.DataFrame({"Precios de Rapanui":precios_de_rapanui()})
rapanui_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5f775ddeb8>]],
#       dtype=object)
