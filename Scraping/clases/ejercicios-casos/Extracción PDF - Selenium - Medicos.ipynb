# %% [markdown]
# ### En esta notebook...
#
# - Mining del texto de la cartilla médica de Medicus en formato .pdf
# - Extracción de los nombres por especialidad y zona
# - Consulta de los nombres en doctoralia
# - Busqueda de coincidencias _fuzzy_
# - Scraping de la info
# - Inserción en DataFrame
# - Selección del médico mejor puntuado

# %%
import os
import re
import pandas as pd
import numpy as np
from time import sleep
from collections import defaultdict
from lxml import html
pd.options.display.float_format = '{:,.2f}'.format
pd.options.display.max_colwidth = 200

# %%
#!pip install fuzzywuzzy[speedup]
#!pip install fuzzysearch

# %%
from fuzzysearch import find_near_matches
from fuzzywuzzy import fuzz
import textract
from utils import init_chrome

# %%
def parse_med_data(html_):
    """Parses doctoralia search page"""
    
    dom = html.fromstring(html_)
    data = []
    for e in dom.xpath('//div[@class="dp-doctor-card dp-doctor-card-md"]/parent::div'):
        name = e.xpath('.//a[@data-ga-label="Doctor Name"]')[0].text.strip()
        profile_url = e.xpath('.//a[@data-ga-label="Doctor Name"]')[0].get('href').partition('#')[0]
        try:
            address = e.xpath('.//div[@class="address-name"]//span[@class="street"]')[0].text
        except:
            address = ''
        try:
            score = int(e.xpath('.//a[@data-ga-label="Reviews"]//@data-score')[0])
            n = int(re.search('\d+', e.xpath('.//span[@data-score]/span')[0].text).group(0))
        except:
            score,n = 0, 0

        data.append((name, address, score, n, profile_url))

    return pd.DataFrame(data, columns = 'name, address, score, n, profile_url'.split(', '))

# %%
path = '/home/matias/Matias/Programas Varios/corporate_area_metropolitana.pdf'
text = textract.process(path).decode('utf8')
pages = re.split('CARTILLA CORPORATE\n31/07/2019\n\nPágina \d+? de 213\n\n\x0c', text)

cartilla = defaultdict(lambda: defaultdict(list))
cuerpo_medico = ''
for i in range(1,len(pages)-1):
    tipo, zona, txt = re.split('\n\n?', pages[i], maxsplit=2)
    
    if tipo != 'CUERPO MEDICO':
        continue    
    
    cuerpo_medico += txt
    
    parts = re.split('\n\n(?=[A-Z ]+?\n)', txt.strip('\n\n'))
    med = {p.split('\n')[0]: [re.sub('\n|\(\d+\)', ' ', p).strip() for p in re.findall('(?<=\n)'
                                                                       '('
                                                                       '(?:DRA?\.|CENTRO|CONS|CLI|SANA|HOSP|ALTER)'
                                                                       '[A-Z, ]+'
                                                                       '(?:\n?(?:[A-Z]+?)|\n?(?:\(\d+\))?)*'
                                                                       ')'
                                                                       '(?=\n|$)',
                                                                       p)] for p in parts}
    for k in med:
        cartilla[zona][k] += med[k]

# %%
len(text), len(cuerpo_medico)
# Out:
# (605018, 394452)

# %%
cartilla['CAPITAL FEDERAL'].keys()
# Out:
# dict_keys(['ADOLESCENCIA', 'ALERGIA E INMUNOLOGIA', 'ANATOMIA PATOLOGICA', 'ANATOMIA PATOLOGICA INFANTIL', 'ANATOMIA PATOLOGICA PULMONAR', 'ANDROLOGIA', 'CARDIOLOGIA', 'ERGOMETRIA', 'HOLTER', 'CARDIOLOGIA INFANTIL', 'ECOCARDIOGRAMA', 'ELECTROCARDIOGRAMA', 'CIRUGIA BARIATRICA', 'CIRUGIA CARDIOVASCULAR', 'CIRUGIA DE CABEZA Y CUELLO', 'CIRUGIA DE CADERA', 'CIRUGIA DE COLON Y RECTO', 'CIRUGIA DE COLUMNA', 'CIRUGIA DE MANO', 'CIRUGIA DEL QUEMADO', 'CIRUGIA GENERAL', 'CIRUGIA INFANTIL', 'CIRUGIA PERCUTANEA', 'CIRUGIA PLASTICA Y REPARADORA', 'CIRUGIA PLASTICA Y REPARADORA INFANTIL', 'CIRUGIA TORACICA', 'CIRUGIA VASCULAR PERIFERICA', 'TRATAMIENTO FLEBOESCLEROSANTE', 'CITODIAGNOSTICO', 'CLINICA MEDICA', 'DERMATOLOGIA', 'DERMATOLOGIA INFANTIL', 'DERMATOPATOLOGIA', 'DIABETOLOGIA Y NUTRICION', 'DIABETOLOGIA Y NUTRICION INFANTOJUVENIL', 'ENDOCRINOLOGIA Y METABOLISMO', 'ENDOCRINOLOGIA Y METABOLISMO INFANTIL', 'FONOAUDIOLOGIA', 'CENTRO MEDICUS AZCUENAGA', 'GASTROENTEROLOGIA', 'ECOGRAFIAS ABDOMINALES', 'GASTROENTEROLOGIA INFANTIL', 'GERIATRIA', 'GINECOLOGIA', 'CRIOCIRUGIA', 'ENDOCRINOLOGIA GINECOLOGICA', 'LAPARASCOPIA DIAGNOSTICA Y OPERATORIA', 'MICROHISTEROSCOPIA', 'PATOLOGIA MAMARIA', 'UROGINECOLOGIA', 'GINECOLOGIA PEDIATRICA Y DE LA ADOLESCENCIA', 'HEMATOLOGIA', 'HEMATOLOGIA INFANTIL', 'HEMODINAMIA', 'HEMODINAMIA INFANTIL', 'HEMOTERAPIA', 'HEPATOLOGIA', 'INFECTOLOGIA', 'CONSULTORIOS EXTERNOS', 'INFECTOLOGIA INFANTIL', 'KINESIOLOGIA', 'NEFROLOGIA', 'NEFROLOGIA INFANTIL', 'NEONATOLOGIA', 'NEUMONOLOGIA', 'NEUMONOLOGIA INFANTIL', 'NEUROCIRUGIA', 'NEUROCIRUGIA INFANTIL', 'NEUROLOGIA', 'ELECTROMIOGRAFIA Y NEUROCONDUCCION', 'POTENCIAL EVOCADO SOMATOSENSITIVO', 'NEUROLOGIA INFANTIL', 'NEUROOTOLOGIA', 'NUTRICION', 'NUTRICION INFANTIL', 'OBSTETRICIA', 'OFTALMOLOGIA', 'CORNEA', 'INFECTOLOGIA OCULAR', 'NEUROOFTALMOLOGIA', 'PARPADOS', 'RETINA', 'OFTALMOLOGIA INFANTIL', 'PREMATUROS', 'ONCOHEMATOLOGIA INFANTIL', 'ONCOLOGIA CLINICA', 'ONCOLOGIA INFANTIL', 'ORTOPTISTA', 'OTORRINOLARINGOLOGIA', 'OTORRINOLARINGOLOGIA INFANTIL', 'PEDIATRIA', 'PROCTOLOGIA', 'RADIOTERAPIA', 'REUMATOLOGIA', 'REUMATOLOGIA INFANTIL', 'TOXICOLOGIA', 'TRATAMIENTO DEL DOLOR', 'TRAUMATOLOGIA Y ORTOPEDIA', 'CADERA', 'COLUMNA', 'MIEMBROS SUPERIORES', 'TRAUMATOLOGIA Y ORTOPEDIA INFANTIL', 'UROLOGIA', 'UROLOGIA INFANTIL'])

# %%
cartilla['CAPITAL FEDERAL']['CARDIOLOGIA']

# %%
q = 'URO|DERMA|CLINICA MEDICA|CARDIO'
cartilla['CAPITAL FEDERAL'][q] = list(set([m for k in cartilla['CAPITAL FEDERAL'].keys() for m in cartilla['CAPITAL FEDERAL'][k] if re.search(q, k)]))

# %% [raw]
# zona = 'CAPITAL FEDERAL'
# especialidad = q
# df = []
#
# n = len(cartilla[zona][especialidad])
# driver = init_chrome(headless=True)
#
# print(n)
# for i in range(n):
#     print(i, end=' ')
#     med = cartilla[zona][especialidad][i].title()
#     url = f"https://www.doctoraliar.com/buscar?q={med} {especialidad}&loc=Capital%20Federal" #&filters%5Binsurances%5D%5B%5D=7 #&page=2
#     driver.get(url)
#     sleep(np.random.randint(3, 5))
#     data = parse_med_data(driver.page_source)
#     data['search_name'] = med
#
#     # while page...
#     all_data.append(data)
#
# df = pd.concat(df)
# df.to_csv(f'df_{q}.csv')

# %%
# Pandas

# %%
df = df
df = df[~df['profile_url'].duplicated()]
df = df.reset_index(drop=True)
df = df.sort_values(['n'], ascending=False)

# %%
df.shape
# Out:
# (751, 8)

# %%
def custom_ratio(str1, str2):
    # Usar que 
    # en la cartilla es DR Apellido, Nombre, Nombre
    # en el sitio es DR nombre apellido
    #re.sub('dra?.?\w+', '')
    return fuzz.token_sort_ratio(str1, str2)

# %%
df['dist'] = df.apply(lambda x: custom_ratio(x['name'], x['search_name']), axis=1)

# %%
df['match'] = df['dist'] >= 80

# %%
df[df['match']][['name', 'search_name', 'profile_url', 'n', 'dist', 'score']].sort_values('n')
# Out:
#                               name                         search_name  \
# 586       Dra. Julieta Finkelstein           Dra. Finkelstein, Julieta
# 620            Liliana Noemí Banin                 Dra. Banin, Liliana
# 600          Dr. Narciso J. Bolomo           Dr. Bolomo, Narciso Julio
# 655          Dr. Martín J. Solanet                  Dra. Mato, Marta J
# 641      Horacio Alejandro Argente       Dr. Alleva, Alejandro Horacio
# 642            Jorge Alberto Scala          Dr. Pascual, Jorge Alberto
# 559    Dr. Carlos M. Grasso Fontan    Dr. Grasso Fontan, Carlos Miguel
# 174                   Sandra Braun            Dra. Braun, Sandra Noemi
# 142            Dr. Mariano Taverna           Dr. Pages, Martin Mariano
# 182  Dra. María Fernanda Moschione        Dra. Sanchez, Maria Fernanda
# 235         Miguel Angel Renovales           Dr. Miranda, Miguel Angel
# 236           Miguel Angel Murrone           Dr. Miranda, Miguel Angel
# 121        Dr. Alberto E. Irigoyen              Dr. Marty, Alberto J E
# 42          Dra. Graciela Lecuenis           Dra. Pellegrino, Graciela
# 51             Dr. Ricardo Galante                  Dr. Medel, Ricardo
# 54           Dr. Ricardo Pampliega                  Dr. Medel, Ricardo
# 73              Dr. Guillermo Juan        Dr. Manente, Diego Guillermo
# 352                Maria Ines Ruiz             Dra. Muzzio, Maria Ines
# 360       Dr. Guillermo S. Wilhelm            Dr. Rosenbaum, Guillermo
# 399      Dr. Hernán Martinez Soler  Dr. Martinez Soler, Hernan Benigno
# 634                 Rosalia Maguid         Dra. Maguid, Rosalia Myrian
# 287         Alejandro Luis Lardaro        Dr. Crovetto, Luis Alejandro
# 320       Dra. Mireya Aznar Gerber           Dra. Aznar Gerber, Mireya
# 456          Dr. Fernando J. Raspi                 Dr. Lamas, Fernando
# 702         Carlos Alberto Rostand         Dr. Miranda, Carlos Alberto
# 691           Dr. Claudio M. Serio            Dr. Pagano, Claudio Omar
# 495    Consultorios Médicos Ateneo      Consultorios Medicus Caballito
# 589     Dra. Miriam G. Chadarevian   Dra. Chadarevian, Miriam Graciela
# 702                           https://www.doctoraliar.com/carlos-alberto-rostand/medico-clinico/saavedra
# 691                                https://www.doctoraliar.com/claudio-m-serio/medico-clinico/avellaneda
# 495                                     https://www.doctoraliar.com/clinicas/consultorios-medicos-ateneo
# 589                      https://www.doctoraliar.com/miriam-g-chadarevian/medico-clinico/capital-federal
# 669                            https://www.doctoraliar.com/marina-penalba/medico-clinico/capital-federal
# 157                          https://www.doctoraliar.com/maria-laura-daud/medico-clinico/capital-federal
# 421                    https://www.doctoraliar.com/maria-cristina-picerno/medico-clinico/capital-federal
# 746                         https://www.doctoraliar.com/luciana-m-arburua/medico-clinico/capital-federal
# 592                      https://www.doctoraliar.com/marisa-ramos-mazzino/medico-clinico/capital-federal
# 685                https://www.doctoraliar.com/claudio-d-iungman/medico-clinico-geriatra/capital-federal
# 659                       https://www.doctoraliar.com/romina-paola-erlich/medico-clinico/capital-federal
# 247                            https://www.doctoraliar.com/carlos-a-celso/medico-clinico/capital-federal
# 524                          https://www.doctoraliar.com/gisela-di-stilio/medico-clinico/capital-federal
# 202                              https://www.doctoraliar.com/jose-l-kogan/medico-clinico/capital-federal
# 69                          https://www.doctoraliar.com/guillermo-mendoza/medico-clinico/capital-federal
# 464              https://www.doctoraliar.com/roberto-m-dervich/cardiologo-medico-clinico/capital-federal
# 101                        https://www.doctoraliar.com/luis-armando-arata/medico-clinico/capital-federal
# 743                            https://www.doctoraliar.com/jose-m-surraco/medico-clinico/capital-federal
# 0                               https://www.doctoraliar.com/raul-a-aphalo/medico-clinico/capital-federal
# 221                                             https://www.doctoraliar.com/clinicas/centro-medico-junin
# 224                                           https://www.doctoraliar.com/clinicas/centro-medico-cervino
#
#       n  dist  score
# 586   0   100      0
# 620   0    74      0
# 600   0    90      0
# 655   0    71      0
# 641   0    77      0
# 642   0    84      0
# 559   0    91      0
# 174   0    71      0
# 142   0    73      0
# 182   0    83      0
# 235   0    71      0
# 236   0    74      0
# 121   0    73      0
# 42    0    73      0
# 51    0    71      0
# 54    0    72      0
# 73    0    70      0
# 352   0    72      0
# 360   0    73      0
# 399   0    84      0
# 634   0    72      0
# 287   0    75      0
# 320   0   100      0
# 456   0    78      0
# 702   0    81      0
# 691   0    70      0
# 495   0    79      0
# 589   0    87      0
# 669   1    70      5
# 157   1    70      5
# 421   1    72      5
# 746   1    70      5
# 592   2    87      5
# 685   2    71      5
# 659   2   100      5
# 247   3    75      5
# 524   3    70      5
# 202   3    78      5
# 69    3    70      5
# 464   4    76      5
# 101   4    89      5
# 743   5    86      5
# 0     6    81      5
# 221  17    72      5
# 224  18    82      5

# %%
#df['check'] = df.apply(lambda x: d(' '.join(x['address'].split()), x['search_name'].lower(), cuerpo_medico.lower()))

# %%
cardios = df[df['profile_url'].str.contains('cardio')]
cardios.shape, len(cartilla[zona][especialidad])
# Out:
# ((0, 6), 252)

# %%
import webbrowser

# %%
for i in range(3):
    webbrowser.open_new_tab(df.iloc[i]['profile_url'])

# %%
#url = f"https://www.google.com/search?q={query}&ie=utf-8&oe=utf-8"
webbrowser.open_new_tab(driver.current_url)
#re.search('.{,100}'+address+'.{,100}', cuerpo_medico, flags=re.DOTALL|re.IGNORECASE).group(0)
