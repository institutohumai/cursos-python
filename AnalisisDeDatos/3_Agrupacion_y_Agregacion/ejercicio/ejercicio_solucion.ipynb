# %% [markdown]
# <a href="https://colab.research.google.com/github/institutohumai/cursos-python/blob/master/AnalisisDeDatos/3_Agrupacion_y_Agregacion/ejercicio/ejercicio.ipynb"> <img src='https://colab.research.google.com/assets/colab-badge.svg' /> </a>
# <div align="center"> Recordá abrir en una nueva pestaña </div>
#
# ## Parte A
# Para esta parte vamos a trabajar sobre el mismo DataFrame que usamos en clase pero agrupando a nivel de comunidad autónoma (Cod_CCAA). En este caso vamos a traer también las descripciones y vamos a hacer un join para formar un único data set.

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('https://datasets-humai.s3.amazonaws.com/datasets/parodesprov.csv')

# %%
df_descripciones = pd.read_csv('https://datasets-humai.s3.amazonaws.com/datasets/comunidades_descripcion.csv')

# %% [markdown]
# Unan ambos DataFrames utilizando la función pd.merge()

# %%
df = df.merge(df_descripciones,left_on='Cod_CCAA',right_on='Código')

# %% [markdown]
# Construir el DataFrame de comunidades autónomas, incluyendo la densidad, la proporción de paro y la cantidad de municipios.

# %%
df_ccaa = df.groupby('Literal').aggregate({'Shape__Area':'sum',
                                       'PAD_1C02':'sum',
                                       'TotalParoRegistrado':'sum',
                                       'Codigo':'size'}).reset_index()

# %%
df_ccaa['Densidad'] = df_ccaa['PAD_1C02'] / df_ccaa['Shape__Area']

# %%
df_ccaa['Proporcion_Paro'] = df_ccaa['TotalParoRegistrado'] / df_ccaa['PAD_1C02']

# %%
df_ccaa.columns
# Out:
# Index(['Literal', 'Shape__Area', 'PAD_1C02', 'TotalParoRegistrado', 'Codigo',
#        'Densidad', 'Proporcion_Paro'],
#       dtype='object')

# %%
df_ccaa.columns = ['CCAA', 'Area', 'Poblacion', 'TotalParoRegistrado',
       'Cantidad_Municipios', 'Densidad', 'Proporcion_Paro']

# %% [markdown]
# Habíamos visto que el promedio de la proporción de paro en los municipios con una densidad menor a la mediana es más bajo.. ¿Se cumple lo mismo para las provincias?

# %%
mediana_densidad = df_ccaa['Densidad'].median()

# %%
df_ccaa.query('Densidad > @mediana_densidad')['Proporcion_Paro'].mean()
# Out:
# 0.08842061984034848

# %%
df_ccaa.query('Densidad <= @mediana_densidad')['Proporcion_Paro'].mean()
# Out:
# 0.08219794142256939

# %% [markdown]
# ¿Cuál es la comunidad autónoma con mayor cantidad de municipios?

# %%
df_ccaa.sort_values('Cantidad_Municipios',ascending=False).head(1)
# Out:
#               CCAA          Area  Poblacion  TotalParoRegistrado  \
# 7  Castilla y León  3.389913e+11  4873320.0             361767.0
#
#    Cantidad_Municipios  Densidad  Proporcion_Paro
# 7                 4496  0.000014         0.074234

# %% [markdown]
# ## Parte B
# Para esta parte usaremos el siguiente [dataset](https://data.buenosaires.gob.ar/dataset/terrenos-valor-oferta) de Datos Abiertos de CABA, a partir de un relevamiento muestral de los avisos publicados para la venta de departamentos en el año 2020. Se detalla el valor de publicacion, metros cuadrados, antiguedad, cantidad de ambientes, ubicacion, etc.

# %% [markdown]
# Importamos los paquetes necesarios y cargamos los datos.

# %%
import numpy as np
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks")
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df = pd.read_csv("Terrenos-en-venta-2020 (4).csv",encoding = "latin1", sep=",")

# %%
df.head()
# Out:
#                         DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  \
# 0                  RIVADAVIA 3500         190     150000    12000000      790
# 1                    PRINGLES 100         242     230000    18400000      950
# 2  PERON, JUAN DOMINGO, TTE. 3400         211     265000    21200000     1256
# 3                     MEXICO 4000         320     300000    24000000      938
# 4                  VENEZUELA 4067         250     305000    24400000     1220
#
#    PESOSM2  COTIZACION TRIMESTRE_   BARRIO  COMUNA_
# 0    63158          80     CUARTO  ALMAGRO        5
# 1    76033          80     CUARTO  ALMAGRO        5
# 2   100474          80     CUARTO  ALMAGRO        5
# 3    75000          80     CUARTO  ALMAGRO        5
# 4    97600          80     CUARTO  ALMAGRO        5

# %%
df.shape
# Out:
# (10301, 10)

# %%
df.isnull()
# Out:
#        DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  PESOSM2  \
# 0          False       False      False       False    False    False
# 1          False       False      False       False    False    False
# 2          False       False      False       False    False    False
# 3          False       False      False       False    False    False
# 4          False       False      False       False    False    False
# ...          ...         ...        ...         ...      ...      ...
# 10296      False       False      False       False    False    False
# 10297      False       False      False       False    False    False
# 10298      False       False      False       False    False    False
# 10299      False       False      False       False    False    False
# 10300      False       False      False       False    False    False
#
#        COTIZACION  TRIMESTRE_  BARRIO  COMUNA_
# 0           False       False   False    False
# 1           False       False   False    False
# 2           False       False   False    False
# 3           False       False   False    False
# 4           False       False   False    False
# ...           ...         ...     ...      ...
# 10296       False       False   False    False
# 10297       False       False   False    False
# 10298       False       False   False    False
# 10299       False       False   False    False
# 10300       False       False   False    False
#
# [10301 rows x 10 columns]

# %%
df[df.isnull().any(axis=1)]
# Out:
#      DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  PESOSM2  \
# 2256       NaN         323    1600000   102400000     4954   317028
# 2976       NaN        1100    3500000   224000000     3182   203636
# 3017       NaN        1050     520000    33280000      495    31695
# 3981       NaN         221     420000    26880000     1900   121629
# 3985       NaN         128     350000    22400000     2734   175000
# 4164       NaN         260     450000    28800000     1731   110769
#
#       COTIZACION TRIMESTRE_            BARRIO  COMUNA_
# 2256          64    SEGUNDO            NUÃEZ       13
# 2976          64    SEGUNDO      VILLA CRESPO       15
# 3017          64    SEGUNDO      VILLA CRESPO       15
# 3981          64    SEGUNDO  PARQUE PATRICIOS        4
# 3985          64    SEGUNDO  PARQUE PATRICIOS        4
# 4164          64    SEGUNDO        VILLA LURO       10

# %%
df.dropna(inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [DIRECCION, PROPIEDADS, PRECIOUSD, PRECIOPESO, DOLARM2, PESOSM2, COTIZACION, TRIMESTRE_, BARRIO, COMUNA_]
# Index: []

# %% [markdown]
# ### Ejercicio 1.
# ¿Cuál es el valor promedio del metro cuadrado en la CABA?

# %%
df.head()
# Out:
#                         DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  \
# 0                  RIVADAVIA 3500         190     150000    12000000      790
# 1                    PRINGLES 100         242     230000    18400000      950
# 2  PERON, JUAN DOMINGO, TTE. 3400         211     265000    21200000     1256
# 3                     MEXICO 4000         320     300000    24000000      938
# 4                  VENEZUELA 4067         250     305000    24400000     1220
#
#    PESOSM2  COTIZACION TRIMESTRE_   BARRIO  COMUNA_
# 0    63158          80     CUARTO  ALMAGRO        5
# 1    76033          80     CUARTO  ALMAGRO        5
# 2   100474          80     CUARTO  ALMAGRO        5
# 3    75000          80     CUARTO  ALMAGRO        5
# 4    97600          80     CUARTO  ALMAGRO        5

# %%
df.describe()
# Out:
#        PROPIEDADS      PRECIOUSD       PRECIOPESO     DOLARM2       PESOSM2  \
# count 10295.00000    10295.00000      10295.00000 10295.00000   10295.00000
# mean    455.75949   904587.72142   60784664.20583  2357.56824  157850.57261
# std     766.96855  1131244.57397   78249925.68569  1600.37164  107529.32500
# min      30.00000    68000.00000    4352000.00000   355.00000   22705.00000
# 25%     200.00000   350000.00000   23520000.00000  1238.00000   83228.00000
# 50%     291.00000   580000.00000   38250000.00000  1918.00000  128321.00000
# 75%     433.00000   980000.00000   64000000.00000  3019.00000  200836.50000
# max   14303.00000 16000000.00000 1280000000.00000 21429.00000 1714286.00000
#
#        COTIZACION     COMUNA_
# count 10295.00000 10295.00000
# mean     67.21253     9.25566
# std       4.01777     4.32894
# min      64.00000     1.00000
# 25%      64.00000     5.00000
# 50%      67.00000    10.00000
# 75%      70.00000    13.00000
# max      80.00000    15.00000

# %%
df["DOLARM2"].mean()
# Out:
# 2357.5682370082563

# %% [markdown]
# ### Ejercicio 2.
# a) Dividir las propiedades por cuartiles de precios en dólares.
#
# b) ¿Cuáles son los barrios con más domicilios en venta dentro del cuartil más barato de CABA?

# %%
df["Cuartiles"]=pd.qcut(df["PRECIOUSD"],4)

# %%
df["Cuartiles"]
# Out:
# 0        (67999.999, 350000.0]
# 1        (67999.999, 350000.0]
# 2        (67999.999, 350000.0]
# 3        (67999.999, 350000.0]
# 4        (67999.999, 350000.0]
#                  ...
# 10296     (350000.0, 580000.0]
# 10297     (580000.0, 980000.0]
# 10298     (580000.0, 980000.0]
# 10299     (580000.0, 980000.0]
# 10300     (350000.0, 580000.0]
# Name: Cuartiles, Length: 10295, dtype: category
# Categories (4, interval[float64, right]): [(67999.999, 350000.0] < (350000.0, 580000.0] <
#                                            (580000.0, 980000.0] < (980000.0, 16000000.0]]

# %%
df.head()
# Out:
#                         DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  \
# 0                  RIVADAVIA 3500         190     150000    12000000      790
# 1                    PRINGLES 100         242     230000    18400000      950
# 2  PERON, JUAN DOMINGO, TTE. 3400         211     265000    21200000     1256
# 3                     MEXICO 4000         320     300000    24000000      938
# 4                  VENEZUELA 4067         250     305000    24400000     1220
#
#    PESOSM2  COTIZACION TRIMESTRE_   BARRIO  COMUNA_              Cuartiles
# 0    63158          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 1    76033          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 2   100474          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 3    75000          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 4    97600          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]

# %%
df["Cuartiles_cat"]=pd.qcut(df["PRECIOUSD"],4,labels=[1,2,3,4])

# %%
df
# Out:
#                              DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  \
# 0                       RIVADAVIA 3500         190     150000    12000000
# 1                         PRINGLES 100         242     230000    18400000
# 2       PERON, JUAN DOMINGO, TTE. 3400         211     265000    21200000
# 3                          MEXICO 4000         320     300000    24000000
# 4                       VENEZUELA 4067         250     305000    24400000
# ...                                ...         ...        ...         ...
# 10296     BONORINO, ESTEBAN, Cnel. 300         149     430000    27412500
# 10297               RIVERA INDARTE 100         500     790000    50362500
# 10298  ALVAREZ, DONATO, Tte. Gral. 200         771     690000    43987500
# 10299      ALBERDI, JUAN BAUTISTA 3100         409     800000    51000000
# 10300               TRELLES, MANUEL R.         280     495000    31680000
#
#        DOLARM2  PESOSM2  COTIZACION TRIMESTRE_        BARRIO  COMUNA_  \
# 0          790    63158          80     CUARTO       ALMAGRO        5
# 1          950    76033          80     CUARTO       ALMAGRO        5
# 2         1256   100474          80     CUARTO       ALMAGRO        5
# 3          938    75000          80     CUARTO       ALMAGRO        5
# 4         1220    97600          80     CUARTO       ALMAGRO        5
# ...        ...      ...         ...        ...           ...      ...
# 10296     2886   183976          64     PRIMER  FLORES NORTE        7
# 10297     1580   100725          64     PRIMER  FLORES NORTE        7
# 10298      895    57052          64     PRIMER  FLORES NORTE        7
# 10299     1956   124694          64     PRIMER  FLORES NORTE        7
# 10300     1768   113143          64    SEGUNDO  FLORES NORTE        7
#
#                    Cuartiles Cuartiles_cat
# 0      (67999.999, 350000.0]             1
# 1      (67999.999, 350000.0]             1
# 2      (67999.999, 350000.0]             1
# 3      (67999.999, 350000.0]             1
# 4      (67999.999, 350000.0]             1
# ...                      ...           ...
# 10296   (350000.0, 580000.0]             2
# 10297   (580000.0, 980000.0]             3
# 10298   (580000.0, 980000.0]             3
# 10299   (580000.0, 980000.0]             3
# 10300   (350000.0, 580000.0]             2
#
# [10295 rows x 12 columns]

# %% [markdown]
# Usando groupby()

# %%
df.groupby(["BARRIO","Cuartiles_cat"]).count()["Cuartiles"].to_frame().reset_index()
# Out:
#             BARRIO Cuartiles_cat  Cuartiles
# 0        AGRONOMIA             1         13
# 1        AGRONOMIA             2         27
# 2        AGRONOMIA             3         22
# 3        AGRONOMIA             4         17
# 4          ALMAGRO             1         31
# ..             ...           ...        ...
# 203  VILLA SOLDATI             4          7
# 204  VILLA URQUIZA             1         92
# 205  VILLA URQUIZA             2        145
# 206  VILLA URQUIZA             3        147
# 207  VILLA URQUIZA             4        106
#
# [208 rows x 3 columns]

# %%
# Lo guardamos en un nuevo df
df_cuartiles=df.groupby(["BARRIO","Cuartiles_cat"]).count()["Cuartiles"].to_frame().reset_index()

# %%
df_cuartiles.rename(columns={"Cuartiles":"Frecuencia"},inplace=True)

# %%
df_cuartiles[df_cuartiles["Cuartiles_cat"]==1].sort_values(by="Frecuencia", ascending=False)
# Out:
#                  BARRIO Cuartiles_cat  Frecuencia
# 72            MATADEROS             1         171
# 108    PARQUE PATRICIOS             1         119
# 84        NUEVA POMPEYA             1         114
# 132       SAN CRISTOBAL             1         104
# 24                 BOCA             1         104
# 68              LINIERS             1          99
# 96    PARQUE AVELLANEDA             1          97
# 144     VELEZ SARSFIELD             1          96
# 204       VILLA URQUIZA             1          92
# 184    VILLA PUEYRREDON             1          90
# 128            SAAVEDRA             1          85
# 60           FLORES SUR             1          84
# 156    VILLA DEL PARQUE             1          83
# 28                BOEDO             1          83
# 168   VILLA GRAL. MITRE             1          82
# 176          VILLA LURO             1          82
# 152        VILLA CRESPO             1          81
# 100    PARQUE CHACABUCO             1          79
# 8             BALVANERA             1          77
# 76         MONTE CASTRO             1          76
# 196    VILLA SANTA RITA             1          69
# 12        BARRACAS ESTE             1          69
# 32            CABALLITO             1          62
# 64             FLORESTA             1          62
# 52         CONSTITUCION             1          49
# 112            PATERNAL             1          45
# 160  VILLA DEVOTO NORTE             1          41
# 188          VILLA REAL             1          41
# 148           VERSALLES             1          40
# 172        VILLA LUGANO             1          40
# 104         PARQUE CHAS             1          39
# 56         FLORES NORTE             1          37
# 192     VILLA RIACHUELO             1          37
# 164    VILLA DEVOTO SUR             1          35
# 4               ALMAGRO             1          31
# 36            CHACARITA             1          29
# 180       VILLA ORTUZAR             1          23
# 200       VILLA SOLDATI             1          13
# 0             AGRONOMIA             1          13
# 40              COGHLAN             1           9
# 80           MONTSERRAT             1           8
# 92              PALERMO             1           7
# 136         SAN NICOLAS             1           6
# 88               NUÃEZ             1           5
# 16       BARRACAS OESTE             1           3
# 120            RECOLETA             1           2
# 44           COLEGIALES             1           2
# 20             BELGRANO             1           2
# 48            COLGIALES             1           0
# 140           SAN TELMO             1           0
# 116       PUERTO MADERO             1           0
# 124              RETIRO             1           0

# %%
df_cuartiles[df_cuartiles["Cuartiles_cat"]==1].sort_values("Frecuencia", ascending=False).head()
# Out:
#                BARRIO Cuartiles_cat  Frecuencia
# 72          MATADEROS             1         171
# 108  PARQUE PATRICIOS             1         119
# 84      NUEVA POMPEYA             1         114
# 132     SAN CRISTOBAL             1         104
# 24               BOCA             1         104

# %% [markdown]
# Usando pivot_table

# %%
dfpivot = df.pivot_table(columns="Cuartiles_cat",index="BARRIO", aggfunc="count")["COMUNA_"].reset_index()

# %%
dfpivot.head()
# Out:
# Cuartiles_cat          BARRIO   1   2    3    4
# 0                   AGRONOMIA  13  27   22   17
# 1                     ALMAGRO  31  79  184  117
# 2                   BALVANERA  77  96  116  140
# 3               BARRACAS ESTE  69  20   20   49
# 4              BARRACAS OESTE   3   0    0    3

# %%
dfpivot = dfpivot.rename_axis(None, axis=1)

# %%
dfpivot.head()
# Out:
#            BARRIO   1   2    3    4
# 0       AGRONOMIA  13  27   22   17
# 1         ALMAGRO  31  79  184  117
# 2       BALVANERA  77  96  116  140
# 3   BARRACAS ESTE  69  20   20   49
# 4  BARRACAS OESTE   3   0    0    3

# %% [markdown]
# Otra forma más sencilla:

# %%
df[df["Cuartiles_cat"]==2]["BARRIO"].value_counts()
# Out:
# VILLA CRESPO          196
# VILLA URQUIZA         145
# SAAVEDRA              133
# BALVANERA              96
# MONTE CASTRO           87
# SAN CRISTOBAL          85
# FLORESTA               80
# FLORES NORTE           79
# ALMAGRO                79
# PARQUE CHAS            76
# BOEDO                  76
# VILLA LURO             76
# CABALLITO              74
# VILLA SANTA RITA       71
# VILLA DEL PARQUE       67
# PALERMO                66
# CHACARITA              61
# VILLA GRAL. MITRE      59
# BOCA                   58
# VILLA DEVOTO NORTE     57
# MATADEROS              55
# VILLA ORTUZAR          54
# VELEZ SARSFIELD        52
# PARQUE PATRICIOS       51
# CONSTITUCION           50
# VILLA PUEYRREDON       47
# PARQUE CHACABUCO       45
# VILLA DEVOTO SUR       42
# PATERNAL               38
# PARQUE AVELLANEDA      37
# NUÃEZ                 37
# VERSALLES              34
# LINIERS                31
# FLORES SUR             28
# AGRONOMIA              27
# COGHLAN                23
# BARRACAS ESTE          20
# COLEGIALES             19
# NUEVA POMPEYA          16
# MONTSERRAT             13
# VILLA LUGANO           12
# SAN TELMO              11
# BELGRANO                6
# SAN NICOLAS             6
# VILLA REAL              4
# RETIRO                  2
# VILLA SOLDATI           1
# Name: BARRIO, dtype: int64

# %% [markdown]
# ### 3. ¿Cómo es el precio promedio para cada decil de tamaño?

# %% [markdown]
# Probamos calculando el tamaño manualmente y vemos que coincide con la columna PROPIEDADS así que la asociamos a esa variable.

# %%
df["PRECIOUSD"]/df["DOLARM2"]
# Out:
# 0       189.87342
# 1       242.10526
# 2       210.98726
# 3       319.82942
# 4       250.00000
#            ...
# 10296   148.99515
# 10297   500.00000
# 10298   770.94972
# 10299   408.99796
# 10300   279.97738
# Length: 10295, dtype: float64

# %%
df['decil']=pd.qcut(df["PROPIEDADS"],10,labels=[i for i in range (0,10)])

# %%
df.head()
# Out:
#                         DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  \
# 0                  RIVADAVIA 3500         190     150000    12000000      790
# 1                    PRINGLES 100         242     230000    18400000      950
# 2  PERON, JUAN DOMINGO, TTE. 3400         211     265000    21200000     1256
# 3                     MEXICO 4000         320     300000    24000000      938
# 4                  VENEZUELA 4067         250     305000    24400000     1220
#
#    PESOSM2  COTIZACION TRIMESTRE_   BARRIO  COMUNA_              Cuartiles  \
# 0    63158          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 1    76033          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 2   100474          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 3    75000          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 4    97600          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
#
#   Cuartiles_cat decil
# 0             1     2
# 1             1     3
# 2             1     2
# 3             1     5
# 4             1     3

# %%
df.groupby(df['decil'])['PRECIOUSD'].mean().to_frame().reset_index()
# Out:
#   decil     PRECIOUSD
# 0     1  360674.93411
# 1     2  431935.33786
# 2     3  546935.44583
# 3     4  569111.30242
# 4     5  652974.35897
# 5     6  690501.85297
# 6     7  746102.81359
# 7     8  897059.64815
# 8     9 1340582.06900
# 9    10 2814914.81535

# %% [markdown]
# ### 4. ¿Cuál es la media de precio por metro cuadrado para cada barrio de la CABA? Ordenar los datos para indicar cuál es el barrio más caro.
# Resolverlo tanto con groupby como con pivot_table.

# %%
df.head()
# Out:
#                         DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  \
# 0                  RIVADAVIA 3500         190     150000    12000000      790
# 1                    PRINGLES 100         242     230000    18400000      950
# 2  PERON, JUAN DOMINGO, TTE. 3400         211     265000    21200000     1256
# 3                     MEXICO 4000         320     300000    24000000      938
# 4                  VENEZUELA 4067         250     305000    24400000     1220
#
#    PESOSM2  COTIZACION TRIMESTRE_   BARRIO  COMUNA_              Cuartiles  \
# 0    63158          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 1    76033          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 2   100474          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 3    75000          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 4    97600          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
#
#   Cuartiles_cat decil
# 0             1     2
# 1             1     3
# 2             1     2
# 3             1     5
# 4             1     3

# %%
df.groupby('BARRIO')['DOLARM2'].mean().sort_values(ascending = False)
# Out:
# BARRIO
# RECOLETA             5834.18750
# RETIRO               5284.16667
# PUERTO MADERO        4906.00000
# BELGRANO             4302.16605
# PALERMO              4283.04671
# NUÃEZ               3778.06701
# SAN NICOLAS          3758.36232
# COLEGIALES           3398.90090
# VILLA CRESPO         3048.57534
# COLGIALES            2900.00000
# CABALLITO            2868.58937
# COGHLAN              2827.58929
# VILLA URQUIZA        2775.79184
# SAN TELMO            2766.21053
# CHACARITA            2679.71713
# MONTSERRAT           2641.30208
# ALMAGRO              2603.32603
# SAAVEDRA             2435.64362
# VILLA ORTUZAR        2414.04500
# BALVANERA            2353.89977
# FLORES NORTE         2315.53767
# VILLA DEVOTO NORTE   2139.86207
# VILLA DEL PARQUE     2124.63218
# BOEDO                1973.63636
# AGRONOMIA            1963.05063
# VILLA DEVOTO SUR     1943.68831
# PARQUE CHAS          1893.88462
# VILLA SANTA RITA     1803.85398
# VILLA LURO           1754.26887
# VILLA PUEYRREDON     1750.33140
# PATERNAL             1721.16814
# PARQUE PATRICIOS     1708.05394
# SAN CRISTOBAL        1633.59459
# FLORESTA             1616.74419
# PARQUE CHACABUCO     1587.98883
# CONSTITUCION         1572.06500
# VILLA GRAL. MITRE    1555.11640
# VELEZ SARSFIELD      1534.15897
# MONTE CASTRO         1528.49524
# PARQUE AVELLANEDA    1424.86826
# LINIERS              1421.54375
# BARRACAS ESTE        1392.29747
# VILLA REAL           1232.35849
# NUEVA POMPEYA        1220.50000
# FLORES SUR           1190.68939
# MATADEROS            1171.20301
# VERSALLES            1134.34177
# BOCA                 1086.25764
# VILLA LUGANO          908.55000
# BARRACAS OESTE        742.00000
# VILLA RIACHUELO       661.27027
# VILLA SOLDATI         593.19048
# Name: DOLARM2, dtype: float64

# %%
df.head()
# Out:
#                         DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  \
# 0                  RIVADAVIA 3500         190     150000    12000000      790
# 1                    PRINGLES 100         242     230000    18400000      950
# 2  PERON, JUAN DOMINGO, TTE. 3400         211     265000    21200000     1256
# 3                     MEXICO 4000         320     300000    24000000      938
# 4                  VENEZUELA 4067         250     305000    24400000     1220
#
#    PESOSM2  COTIZACION TRIMESTRE_   BARRIO  COMUNA_              Cuartiles  \
# 0    63158          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 1    76033          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 2   100474          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 3    75000          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 4    97600          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
#
#   Cuartiles_cat decil
# 0             1     2
# 1             1     3
# 2             1     2
# 3             1     5
# 4             1     3

# %%
df.pivot_table(index = 'BARRIO', aggfunc={'DOLARM2':'mean'}).sort_values(by='DOLARM2',ascending=False).reset_index()
# Out:
#                 BARRIO    DOLARM2
# 0             RECOLETA 5834.18750
# 1               RETIRO 5284.16667
# 2        PUERTO MADERO 4906.00000
# 3             BELGRANO 4302.16605
# 4              PALERMO 4283.04671
# 5               NUÃEZ 3778.06701
# 6          SAN NICOLAS 3758.36232
# 7           COLEGIALES 3398.90090
# 8         VILLA CRESPO 3048.57534
# 9            COLGIALES 2900.00000
# 10           CABALLITO 2868.58937
# 11             COGHLAN 2827.58929
# 12       VILLA URQUIZA 2775.79184
# 13           SAN TELMO 2766.21053
# 14           CHACARITA 2679.71713
# 15          MONTSERRAT 2641.30208
# 16             ALMAGRO 2603.32603
# 17            SAAVEDRA 2435.64362
# 18       VILLA ORTUZAR 2414.04500
# 19           BALVANERA 2353.89977
# 20        FLORES NORTE 2315.53767
# 21  VILLA DEVOTO NORTE 2139.86207
# 22    VILLA DEL PARQUE 2124.63218
# 23               BOEDO 1973.63636
# 24           AGRONOMIA 1963.05063
# 25    VILLA DEVOTO SUR 1943.68831
# 26         PARQUE CHAS 1893.88462
# 27    VILLA SANTA RITA 1803.85398
# 28          VILLA LURO 1754.26887
# 29    VILLA PUEYRREDON 1750.33140
# 30            PATERNAL 1721.16814
# 31    PARQUE PATRICIOS 1708.05394
# 32       SAN CRISTOBAL 1633.59459
# 33            FLORESTA 1616.74419
# 34    PARQUE CHACABUCO 1587.98883
# 35        CONSTITUCION 1572.06500
# 36   VILLA GRAL. MITRE 1555.11640
# 37     VELEZ SARSFIELD 1534.15897
# 38        MONTE CASTRO 1528.49524
# 39   PARQUE AVELLANEDA 1424.86826
# 40             LINIERS 1421.54375
# 41       BARRACAS ESTE 1392.29747
# 42          VILLA REAL 1232.35849
# 43       NUEVA POMPEYA 1220.50000
# 44          FLORES SUR 1190.68939
# 45           MATADEROS 1171.20301
# 46           VERSALLES 1134.34177
# 47                BOCA 1086.25764
# 48        VILLA LUGANO  908.55000
# 49      BARRACAS OESTE  742.00000
# 50     VILLA RIACHUELO  661.27027
# 51       VILLA SOLDATI  593.19048

# %% [markdown]
# ¿Y si quisieramos ver la dispersión de precios del M2?

# %%
# Considerando la formula del coeficiente de variación
disp = df.groupby('BARRIO')['DOLARM2'].apply(lambda x: x.std() / x.mean()).sort_values(ascending = False)

# %%
disp
# Out:
# BARRIO
# BOCA                 0.98326
# NUEVA POMPEYA        0.69337
# SAN TELMO            0.64843
# PARQUE PATRICIOS     0.64539
# SAAVEDRA             0.62617
# FLORES SUR           0.61620
# PARQUE CHACABUCO     0.59972
# VILLA LUGANO         0.59116
# CHACARITA            0.57820
# BALVANERA            0.56948
# COGHLAN              0.55486
# RETIRO               0.55477
# SAN NICOLAS          0.55228
# BARRACAS ESTE        0.55036
# VILLA LURO           0.54263
# VILLA URQUIZA        0.53137
# RECOLETA             0.52639
# CABALLITO            0.52058
# BOEDO                0.51876
# VILLA CRESPO         0.50789
# COLEGIALES           0.49733
# VILLA DEVOTO NORTE   0.49466
# PALERMO              0.49451
# MONTSERRAT           0.47774
# VILLA GRAL. MITRE    0.47720
# VILLA ORTUZAR        0.47276
# ALMAGRO              0.47082
# VILLA DEL PARQUE     0.46869
# PATERNAL             0.46811
# VILLA SANTA RITA     0.46618
# PARQUE AVELLANEDA    0.46170
# BELGRANO             0.45840
# VILLA PUEYRREDON     0.45834
# VILLA DEVOTO SUR     0.45067
# VELEZ SARSFIELD      0.44860
# MATADEROS            0.44372
# NUÃEZ               0.44313
# FLORES NORTE         0.44311
# CONSTITUCION         0.43831
# SAN CRISTOBAL        0.43167
# LINIERS              0.43026
# FLORESTA             0.40406
# VERSALLES            0.37764
# MONTE CASTRO         0.36602
# AGRONOMIA            0.35528
# PARQUE CHAS          0.29550
# VILLA REAL           0.25647
# VILLA RIACHUELO      0.25384
# VILLA SOLDATI        0.22919
# PUERTO MADERO        0.20839
# BARRACAS OESTE       0.19783
# COLGIALES                NaN
# Name: DOLARM2, dtype: float64

# %%
# Encontramos una fila con un error en el tipeo de Colegiales.
df["BARRIO"]=df["BARRIO"].replace("COLGIALES","COLEGIALES")

# %%
# Volvemos a crear la variable disp una vez hechos los cambios
disp = df.groupby('BARRIO')['DOLARM2'].apply(lambda x: x.std() / x.mean()).sort_values(ascending = False)

# %%
disp
# Out:
# BARRIO
# BOCA                 0.98326
# NUEVA POMPEYA        0.69337
# SAN TELMO            0.64843
# PARQUE PATRICIOS     0.64539
# SAAVEDRA             0.62617
# FLORES SUR           0.61620
# PARQUE CHACABUCO     0.59972
# VILLA LUGANO         0.59116
# CHACARITA            0.57820
# BALVANERA            0.56948
# COGHLAN              0.55486
# RETIRO               0.55477
# SAN NICOLAS          0.55228
# BARRACAS ESTE        0.55036
# VILLA LURO           0.54263
# VILLA URQUIZA        0.53137
# RECOLETA             0.52639
# CABALLITO            0.52058
# BOEDO                0.51876
# VILLA CRESPO         0.50789
# COLEGIALES           0.49593
# VILLA DEVOTO NORTE   0.49466
# PALERMO              0.49451
# MONTSERRAT           0.47774
# VILLA GRAL. MITRE    0.47720
# VILLA ORTUZAR        0.47276
# ALMAGRO              0.47082
# VILLA DEL PARQUE     0.46869
# PATERNAL             0.46811
# VILLA SANTA RITA     0.46618
# PARQUE AVELLANEDA    0.46170
# BELGRANO             0.45840
# VILLA PUEYRREDON     0.45834
# VILLA DEVOTO SUR     0.45067
# VELEZ SARSFIELD      0.44860
# MATADEROS            0.44372
# NUÃEZ               0.44313
# FLORES NORTE         0.44311
# CONSTITUCION         0.43831
# SAN CRISTOBAL        0.43167
# LINIERS              0.43026
# FLORESTA             0.40406
# VERSALLES            0.37764
# MONTE CASTRO         0.36602
# AGRONOMIA            0.35528
# PARQUE CHAS          0.29550
# VILLA REAL           0.25647
# VILLA RIACHUELO      0.25384
# VILLA SOLDATI        0.22919
# PUERTO MADERO        0.20839
# BARRACAS OESTE       0.19783
# Name: DOLARM2, dtype: float64

# %%
disp.to_frame().plot(kind='barh',figsize=(10,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ### 5. Dada la siguiente [fuente](https://data.buenosaires.gob.ar/dataset/terrenos-valor-oferta/resource/c9a6fed8-da1d-460e-92a8-e0213d68f59c ) con similar información pero de 2019:
# ### ¿Qué porcentaje de propiedades que estaban en venta durante 2019 siguieron estando en 2020?

# %%
df19 = pd.read_csv("Terrenos-en-venta-2019 (2).csv",encoding="latin1", sep=",")

# %%
df19.shape
# Out:
# (5006, 13)

# %%
df19.head()
# Out:
#   OPERACION     TIPO      LATITUD     LONGITUD    M2TOTAL  \
# 0       VTA  TERRENO  -34.6294378  -58.4498948  235.00000
# 1       VTA  TERRENO  -34.6289663  -58.4483573 1629.00000
# 2       VTA  TERRENO  -34.6265344  -58.4326234  438.00000
# 3       VTA  TERRENO  -34.6248406  -58.4317985  272.00000
# 4       VTA  TERRENO   -34.622629    -58.44079  600.00000
#
#                      DIRECCION CAMBIO     PRECIOUSD  PRECIOARS  PRECIOUSDM  \
# 0   Malvinas Argentinas al 400  45.00 1100000.00000   49500000  4681.00000
# 1          Jose Bonifacio 1520  45.00 1400000.00000   63000000   859.00000
# 2          BONIFACIO  JOSE 400  45.00 2380000.00000  107100000  1062.00000
# 3                 VIEL  al 600  45.00  895000.00000   40275000  3290.00000
# 4  Av. Del Barco Centenera 200  45.00  400000.00000   18000000   667.00000
#
#     PRECIOARSM    BARRIOS  COMUNA
# 0 210645.00000  CABALLITO       6
# 1  38655.00000  CABALLITO       6
# 2  47790.00000  CABALLITO       6
# 3 148050.00000  CABALLITO       6
# 4  30015.00000  CABALLITO       6

# %%
df.shape
# Out:
# (10295, 13)

# %%
# Dado que nuestro único código unificador es la dirección, buscamos la manera de unificar la forma de unificar ambas columnas entre ambos Dataframes.  
df19["DIRECCION"]=df19["DIRECCION"].str.replace("al ","")

# %%
df.head()
# Out:
#                         DIRECCION  PROPIEDADS  PRECIOUSD  PRECIOPESO  DOLARM2  \
# 0                  RIVADAVIA 3500         190     150000    12000000      790
# 1                    PRINGLES 100         242     230000    18400000      950
# 2  PERON, JUAN DOMINGO, TTE. 3400         211     265000    21200000     1256
# 3                     MEXICO 4000         320     300000    24000000      938
# 4                  VENEZUELA 4067         250     305000    24400000     1220
#
#    PESOSM2  COTIZACION TRIMESTRE_   BARRIO  COMUNA_              Cuartiles  \
# 0    63158          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 1    76033          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 2   100474          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 3    75000          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
# 4    97600          80     CUARTO  ALMAGRO        5  (67999.999, 350000.0]
#
#   Cuartiles_cat decil
# 0             1     2
# 1             1     3
# 2             1     2
# 3             1     5
# 4             1     3

# %%
df19.head()
# Out:
#   OPERACION     TIPO      LATITUD     LONGITUD    M2TOTAL  \
# 0       VTA  TERRENO  -34.6294378  -58.4498948  235.00000
# 1       VTA  TERRENO  -34.6289663  -58.4483573 1629.00000
# 2       VTA  TERRENO  -34.6265344  -58.4326234  438.00000
# 3       VTA  TERRENO  -34.6248406  -58.4317985  272.00000
# 4       VTA  TERRENO   -34.622629    -58.44079  600.00000
#
#                      DIRECCION CAMBIO     PRECIOUSD  PRECIOARS  PRECIOUSDM  \
# 0      Malvinas Argentinas 400  45.00 1100000.00000   49500000  4681.00000
# 1          Jose Bonifacio 1520  45.00 1400000.00000   63000000   859.00000
# 2          BONIFACIO  JOSE 400  45.00 2380000.00000  107100000  1062.00000
# 3                    VIEL  600  45.00  895000.00000   40275000  3290.00000
# 4  Av. Del Barco Centenera 200  45.00  400000.00000   18000000   667.00000
#
#     PRECIOARSM    BARRIOS  COMUNA
# 0 210645.00000  CABALLITO       6
# 1  38655.00000  CABALLITO       6
# 2  47790.00000  CABALLITO       6
# 3 148050.00000  CABALLITO       6
# 4  30015.00000  CABALLITO       6

# %%
# Probamos un primer inner join.
df.merge(df19,how="inner", left_on="DIRECCION",right_on="DIRECCION")
# Out:
#             DIRECCION  PROPIEDADS  PRECIOUSD_x  PRECIOPESO  DOLARM2  PESOSM2  \
# 0     QUERANDIES 4200         234       450000    36000000     1923   153846
# 1     QUERANDIES 4200         234       450000    36000000     1923   153846
# 2     QUERANDIES 4200         234       450000    36000000     1923   153846
# 3     QUERANDIES 4200         234       450000    36000000     1923   153846
# 4     QUERANDIES 4200         234       450000    36000000     1923   153846
# ...               ...         ...          ...         ...      ...      ...
# 1872    SAN BLAS 4900         460       543000    34616250     1180    75253
# 1873    SAN BLAS 4900         460       543000    34616250     1180    75253
# 1874    SAN BLAS 4900         460       543000    34616250     1180    75253
# 1875    SAN BLAS 4900         460       543000    34616250     1180    75253
# 1876    SAN BLAS 4900         460       543000    34616250     1180    75253
#
#       COTIZACION TRIMESTRE_           BARRIO  COMUNA_  ...    LATITUD  \
# 0             80     CUARTO          ALMAGRO        5  ...  -34.61105
# 1             80     CUARTO          ALMAGRO        5  ...  -34.61105
# 2             80     CUARTO          ALMAGRO        5  ...  -34.61105
# 3             80     CUARTO          ALMAGRO        5  ...  -34.61105
# 4             80     CUARTO          ALMAGRO        5  ...  -34.61105
# ...          ...        ...              ...      ...  ...        ...
# 1872          64     TERCER  VELEZ SARSFIELD       10  ...   -3462675
# 1873          64     TERCER  VELEZ SARSFIELD       10  ...  -34,62675
# 1874          64     TERCER  VELEZ SARSFIELD       10  ...   -3462675
# 1875          64     TERCER  VELEZ SARSFIELD       10  ...   -3462675
# 1876          64     TERCER  VELEZ SARSFIELD       10  ...  -34.62675
#
#        LONGITUD   M2TOTAL CAMBIO  PRECIOUSD_y PRECIOARS PRECIOUSDM  \
# 0     -58.42643 234.00000  45.00 450000.00000   #VALUE! 1923.00000
# 1     -58.42643 234.00000   43,2 450000.00000  19440000 1923.07692
# 2     -58.42643 234.00000  41.40 410000.00000  16974000 1752.13675
# 3     -58.42643 234.00000  41.40 450000.00000  18630000 1923.07692
# 4     -58.42643 234.00000  38.40 410000.00000  15744000 1752.00000
# ...         ...       ...    ...          ...       ...        ...
# 1872    -585046 373.00000  51.80 520000.00000  26936000 1394.10188
# 1873   -58,5046 373.00000  56,16 520000.00000  29203200 1394.00000
# 1874    -585046 373.00000  58.90 520000.00000  30628000 1394.10188
# 1875    -585046 373.00000  60.38 520000.00000  31397600 1394.00000
# 1876   -58.5046 373.00000  60.50 520000.00000  31460000 1394.00000
#
#       PRECIOARSM          BARRIOS  COMUNA
# 0    86535.00000          ALMAGRO       5
# 1    83074.00000          ALMAGRO       5
# 2    72533.00000          ALMAGRO       5
# 3    79612.00000          ALMAGRO       5
# 4    67277.00000          ALMAGRO       5
# ...          ...              ...     ...
# 1872 72209.00000  VELEZ SARSFIELD      10
# 1873 78287.00000  VELEZ SARSFIELD      10
# 1874 80857.90887  VELEZ SARSFIELD      10
# 1875 84170.00000  VELEZ SARSFIELD      10
# 1876 84337.00000  VELEZ SARSFIELD      10
#
# [1877 rows x 25 columns]

# %% [markdown]
# Encontramos 1877 propiedades en común. Busquemos formas de mejorar esto.

# %%
# Podríamos dropear duplicados dentro de un Dataframe usando drop_duplicates. Subset nos determina qué columna/s vamos a mirar como criterio de fila duplicada.
df = df.drop_duplicates(subset="DIRECCION")
df19 = df19.drop_duplicates(subset= "DIRECCION")

# %% [markdown]
# Pasamos todo a lowercase para ver si matcheamos más propiedades:

# %%
df["DIRECCION"]=df["DIRECCION"].str.lower()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df19["DIRECCION"]=df19["DIRECCION"].str.lower()

# %%
df.columns
# Out:
# Index(['DIRECCION', 'PROPIEDADS', 'PRECIOUSD', 'PRECIOPESO', 'DOLARM2',
#        'PESOSM2', 'COTIZACION', 'TRIMESTRE_', 'BARRIO', 'COMUNA_', 'Cuartiles',
#        'Cuartiles_cat', 'decil'],
#       dtype='object')

# %%
df19.columns
# Out:
# Index(['OPERACION', 'TIPO', 'LATITUD', 'LONGITUD', 'M2TOTAL', 'DIRECCION',
#        'CAMBIO', 'PRECIOUSD', 'PRECIOARS', 'PRECIOUSDM', 'PRECIOARSM',
#        'BARRIOS', 'COMUNA'],
#       dtype='object')

# %%
df_merge = df.merge(df19,how="inner", left_on="DIRECCION",right_on="DIRECCION")

# %%
df_merge.shape
# Out:
# (777, 25)

# %%
777/5006
# Out:
# 0.15521374350779066
